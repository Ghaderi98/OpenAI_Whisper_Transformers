# %%
# !pip install llama-index
# !pip install llam-hub
# !pip install assemblyai
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement llam-hub (from versions: none)
# ERROR: No matching distribution found for llam-hub
# ...

# %%
# !pip list
# Out:
# Package                          Version
# -------------------------------- ---------------------
# absl-py                          1.4.0
# aiohttp                          3.8.6
# aiosignal                        1.3.1
# aiostream                        0.5.2
# alabaster                        0.7.13
# albumentations                   1.3.1
# altair                           4.2.2
# anyio                            3.7.1
# appdirs                          1.4.4
# argon2-cffi                      23.1.0
# argon2-cffi-bindings             21.2.0
# array-record                     0.5.0
# arviz                            0.15.1
# assemblyai                       0.19.0
# astropy                          5.3.4
# astunparse                       1.6.3
# async-timeout                    4.0.3
# atlassian-python-api             3.41.3
# atpublic                         4.0
# attrs                            23.1.0
# audioread                        3.0.1
# ...

# %%
# !pip install llama-hub

# %%
# !pip uninstall llama-hub
# !pip install llama-hub
# Out:
# Found existing installation: llama-hub 0.0.40
# Uninstalling llama-hub-0.0.40:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/LICENSE
#     /usr/local/lib/python3.10/dist-packages/llama_hub-0.0.40.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/llama_hub/*
# Proceed (Y/n)? Y
#   Successfully uninstalled llama-hub-0.0.40
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 12.3 MB/s eta 0:00:00
# ...

# %%
# !python -m pip cache purge
# Out:
# Files removed: 2

# %%
from llama_hub.assemblyai.base import AssemblyAIAudioTranscriptReader

# %%
audio_file="audio.mp3"

# %%
import assemblyai

assemblyai.settings.api_key = '28802fd4f8444feb96084e48461cd8e5'

# %%
Reader=AssemblyAIAudioTranscriptReader(file_path=audio_file)

# %%
import assemblyai
# !pip install assemblyai


audio_file = '/content/audio.mp3'

# Instantiate the reader
reader = AssemblyAIAudioTranscriptReader(file_path=audio_file)
docs=reader.load_data()
print(docs[0].text)
docs[0].metadata={}
# Out:
# ...
# Sam. Just like you did before the accident. Close it. When you're staring into space it's hard to believe you don't remember it woke up in the ambulance. You pieced it all together on the drive. I know you don't remember calling me but I told you even then you look so pretty in a hospital bed I remember you said you were scared and so was I in a standstill on the five. Thought it was unusual. Early traffic. Usually I don't panic. I just wanted to be on time. When I saw the ambulances on the shoulder, I didn't even think of pulling over. I pieced it all together late that night and I know you don't remember going me but I told you even then you look so pretty in a hospital bed I remember you said you were scared and so was I. What if it happened to you on a different day? On a bridge where there wasn't a rail in the way? Or a neighborhood street where the little kids play or the angels crest in the snow or the rain. What if you weren't alone? There were kids in the car. What if you we
# ...
